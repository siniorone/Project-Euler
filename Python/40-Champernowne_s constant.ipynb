# %%
result=1
f=""
a=0
b=1
i=1
ten=1
while ten<10000000:
    f=str(i)
    lenf=len(f)
    a = b
    b += lenf

    if  a <= ten and b > ten :
       z=ten-a
       result *= int(f[z])
       ten *= 10
    i += 1
print(result)
# Out:
# 210
