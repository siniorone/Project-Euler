# %%
import itertools
digits=["1","2","3","4","5","6","7","8","9"]
pandigitals=list(itertools.permutations(digits))
pandigitals.sort(reverse=True)
#------------------------------------------------
def concatenated(n):
    str_n=str(n)
    len_n=len(str_n)
    for i in range(1,5):
        mystr=str_n
        eq=mystr[:i]
        gen=""
        myi=i
        j=1
        while True:
            j+=1
            a=mystr[:myi]
            gen += a
            aa=str(int(eq)*(j))
            mystr=mystr[myi:]
            if aa != mystr[:len(aa)]:break
            else:
                myi=len(aa)
        if gen == str_n : 
            
            return str_n + " is the concatenated product of "+str(eq)+ " and 1 to "+str(j-1)
    return False 
#------------------------------------------------
pandigitalـmultiples={}
for p in pandigitals:
    n=int(''.join(p))
    c=concatenated(n)
    if c : 
        print(c)
        break
# Out:
# 932718654 is the concatenated product of 9327 and 1 to 2
