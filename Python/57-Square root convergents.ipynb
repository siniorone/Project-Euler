# %%
numerator = 3
last_n = 1
denominator = 2
last_d = 1
count=0
for i in range(1,1001):
    mid = numerator
    numerator = numerator * 2 + last_n
    last_n = mid
    mid = denominator
    denominator = denominator * 2 + last_d
    last_d = mid
    if len(str(numerator)) > len(str(denominator)) :
         count += 1
print(count)
# Out:
# 153
