# %%
triangle=set()
pentagonal=set()
hexagonal=set()
i = 2
while True:
    hexagonal.add(int(i*(2*i-1)))
    pentagonal.add(int(i*(3*i-1)/2))
    t=int(i*(i+1)/2)
    triangle.add(t)
    if t in hexagonal and t in pentagonal and t>40755 :
      print(t)
      break
    i+=1
# Out:
# 1533776805
