# %%
def is_prime(n):
    for i in range(2,int(n**.5)+1):
        if n % i == 0 : return False
    return True
i = 3
q = 1
steper = 2
diagon = 3
prime_count = 0
nonprime_count =0
while True :
    #-----------------------------------------
    if i == diagon : 
        if is_prime(i) : 
            prime_count += 1
        else :
            nonprime_count += 1
            
        diagons.add(diagon)
        if q < 4 : q += 1
        else:
           h=prime_count/(nonprime_count + prime_count + 1)  * 100
           if i > 10 and   h < 10 :
              print(f"{steper + 1} {h:2.4f}%")
              break
           steper += 2
           q = 1
        diagon += steper 
        i = diagon
# Out:
# 26241 9.9998%
