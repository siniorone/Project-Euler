# %%
penta={}
for i in range(1,int(1e6)):
  penta[3*(i**2)-i]=i
condition=True
b=2
while condition:
    for a in range(b,0,-1):
        plus=3*(a**2+b**2)-(a+b)
        if plus in penta:
            diff=3*(b**2-a**2)-(b-a)
            if diff in penta:
                p_b=int(b*(3*b-1)/2)
                p_a=int(a*(3*a-1)/2)
                print(f"plus and mines : a:{a} b:{b} diff:{p_b-p_a}")
                condition=False
                break
    b+=1
# Out:
# plus and mines : a:1020 b:2167 diff:5482660
