# %% [markdown]
# ### Special Pythagorean triplet
# ### Problem 9
# A Pythagorean triplet is a set of three natural numbers, a < b < c, for which,
# a^2 + b^2 = c^2
#
# For example, 3^2 + 4^2 = 9 + 16 = 25 = 5^2.
#
# There exists exactly one Pythagorean triplet for which a + b + c = 1000.
# Find the product abc.
#
# ---
# #### persian translation:
# ```
#  سه عدد را در صورتی سه تایی فیثاغورثی می نامیم که شرایط زیر بر قرار باشد
#  a < b < c
#  a^2 + b^2 = c^2
#  به عنوان مثال
#  3^2 + 4^2 = 9 + 16 = 25 = 5^2
#  دقیقا یک سه تایی فیثاغورثی وجود دارد که جمع اعداد آن برابر با 1000 می شود
#  a + b + c = 1000
#  حاصلضرب این اعداد را بیابید؟
# ```

# %%
x = 1000
print(eps)
for a in range(1, x):
    for b in range(a, x):
        if a + b >= x : break
        c = (a ** 2 + b ** 2) ** 0.5
        if (c - int(c)) < eps and a + b + int(c) == 1000:
            product = a * b * int(c)
            print("a:{} b:{} c:{} Sum:{} Product:{}".format(a, b, int(c), a + b + int(c), a * b * int(c)))
# Out:
# 1e-16
# a:200 b:375 c:425 Sum:1000 Product:31875000
